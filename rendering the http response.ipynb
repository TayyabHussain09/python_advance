# %%
from bs4 import BeautifulSoup
import requests

# %%
url="https://medium.com/"

# %%
tayyabsnext = requests.get(url)

# %%
forexample_data=tayyabsnext.content

# %%
Apply_retrieving=BeautifulSoup(forexample_data, "html.parser")

# %%
tayyabsnext.close()

# %%
Apply_retrieving.contents
# Out:
# ['html',
# ...

# %%
print(Apply_retrieving.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <title data-rh="true">
#    Medium – Where good ideas find you.
#   </title>
#   <meta charset="utf-8" data-rh="true"/>
#   <meta content="width=device-width,minimum-scale=1,initial-scale=1,maximum-scale=1" data-rh="true" name="viewport"/>
#   <meta content="#000000" data-rh="true" name="theme-color"/>
#   <meta content="Medium" data-rh="true" name="twitter:app:name:iphone"/>
#   <meta content="828256236" data-rh="true" name="twitter:app:id:iphone"/>
#   <meta content="Medium" data-rh="true" property="al:ios:app_name"/>
#   <meta content="828256236" data-rh="true" property="al:ios:app_store_id"/>
#   <meta content="com.medium.reader" data-rh="true" property="al:android:package"/>
#   <meta content="Medium" data-rh="true" property="al:android:app_name"/>
#   <meta content="542599432471018" data-rh="true" property="fb:app_id"/>
#   <meta content="index,follow" data-rh="true" name="robots"/>
# ...

# %%
Apply_retrieving.title
# Out:
# <title data-rh="true">Medium – Where good ideas find you.</title>

# %%
a=Apply_retrieving.shape
print(a)
# Out:
# None

# %%
for href in Apply_retrieving.findAll('a', href=True):
    print(href ['href'])
# Out:
# /
# https://medium.com/about?autoplay=1
# https://medium.com/membership
# https://about.medium.com/creators/
# /m/signin?operation=login&redirect=https%3A%2F%2Fmedium.com%2F&source=--------------------------lo_home_nav-----------
# /m/signin?operation=register&redirect=https%3A%2F%2Fmedium.com%2F&source=--------------------------lo_home_nav-----------
# /@cajundiscordian?source=home---------0---------------------c1cfc633_8664_41d9_a6b9_b53f5d05f58a-------7
# /@cajundiscordian?source=home---------0---------------------c1cfc633_8664_41d9_a6b9_b53f5d05f58a-------7
# https://cajundiscordian.medium.com/is-lamda-sentient-an-interview-ea64d916d917?source=home---------0---------------------c1cfc633_8664_41d9_a6b9_b53f5d05f58a-------7
# /@bradwray?source=home---------1---------------------c1cfc633_8664_41d9_a6b9_b53f5d05f58a-------7
# /@bradwray?source=home---------1---------------------c1cfc633_8664_41d9_a6b9_b53f5d05f58a-------7
# ...
